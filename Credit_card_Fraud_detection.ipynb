# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/creditcard.csv'

# Load the CSV into a DataFrame
df = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Display the first 5 rows
print("First 5 rows:")
display(df.head())

# Display the last 5 rows
print("Last 5 rows:")
display(df.tail())
# Out:
# First 5 rows:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import sqlite3

# Create an in-memory SQLite database
conn = sqlite3.connect(':memory:')

# Load the DataFrame into a SQL table named "transactions"
df.to_sql('transactions', conn, index=False)

# Show the first 5 rows
print("First 5 rows:")
display(pd.read_sql_query("SELECT * FROM transactions LIMIT 5", conn))
# Out:
# First 5 rows:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Query to count total number of rows
pd.read_sql_query("SELECT COUNT(*) AS total_rows FROM transactions", conn)
# Out:
#    total_rows
# 0      284807

# %%
query = """
SELECT
  Class,
  COUNT(*) AS count
FROM
  transactions
GROUP BY
  Class
"""

pd.read_sql_query(query, conn)
# Out:
#    Class   count
# 0      0  284315
# 1      1     492

# %%
query = """
SELECT
  Class,
  COUNT(*) AS count,
  ROUND(AVG(Amount), 2) AS avg_amount,
  ROUND(MAX(Amount), 2) AS max_amount,
  ROUND(MIN(Amount), 2) AS min_amount
FROM
  transactions
GROUP BY
  Class
"""

pd.read_sql_query(query, conn)
# Out:
#    Class   count  avg_amount  max_amount  min_amount
# 0      0  284315       88.29    25691.16         0.0
# 1      1     492      122.21     2125.87         0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reduce extreme values for better visual clarity
df_viz = df.copy()
df_viz = df_viz[df_viz['Amount'] < 2000]

# Set a clear, colorblind-friendly palette
custom_palette = {0: '#4C72B0', 1: '#DD8452'}  # Blue for non-fraud, orange for fraud

plt.figure(figsize=(12,6))
sns.histplot(
    data=df_viz,
    x='Amount',
    hue='Class',
    bins=100,
    log_scale=(False, True),
    palette=custom_palette,
    element="step",  # improves contrast by outlining each class
    stat="count",
    common_norm=False
)

plt.title("Transaction Amount Distribution by Class", fontsize=14)
plt.xlabel("Transaction Amount ($)", fontsize=12)
plt.ylabel("Transaction Count (Log Scale)", fontsize=12)
plt.legend(title='Class', labels=['Non-Fraud (0)', 'Fraud (1)'])
plt.tight_layout()
plt.show()

# %%
# Create a new column for hour of transaction (rounded down)
df['Hour'] = (df['Time'] // 3600).astype(int)

# Reload into SQL for querying
df.to_sql('transactions', conn, index=False, if_exists='replace')
# Out:
# 284807

# %%
query = """
SELECT
  Hour,
  Class,
  COUNT(*) AS count
FROM
  transactions
GROUP BY
  Hour, Class
ORDER BY
  Hour, Class
"""

df_hourly = pd.read_sql_query(query, conn)
df_hourly.head()
# Out:
#    Hour  Class  count
# 0     0      0   3961
# 1     0      1      2
# 2     1      0   2215
# 3     1      1      2
# 4     2      0   1555

# %%
df[['Time', 'Hour']].head(10)
# Out:
#    Time  Hour
# 0   0.0     0
# 1   0.0     0
# 2   1.0     0
# 3   1.0     0
# 4   2.0     0
# 5   2.0     0
# 6   4.0     0
# 7   7.0     0
# 8   7.0     0
# 9   9.0     0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pivot the SQL result into wide format for plotting
df_pivot = df_hourly.pivot(index='Hour', columns='Class', values='count').fillna(0)
df_pivot.columns = ['Non-Fraud (0)', 'Fraud (1)']

# Plot
plt.figure(figsize=(14,6))
sns.lineplot(data=df_pivot)
plt.title("Hourly Transaction Volume by Class")
plt.xlabel("Hour Since First Transaction")
plt.ylabel("Transaction Count")
plt.legend(title="Class")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Hour', y='Fraud (1)', data=df_pivot, color='#DD8452')
plt.title("Fraudulent Transactions by Hour")
plt.xlabel("Hour Since First Transaction")
plt.ylabel("Fraud Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_pivot['Fraud Rate (%)'] = df_pivot['Fraud (1)'] / (df_pivot['Fraud (1)'] + df_pivot['Non-Fraud (0)']) * 100

plt.figure(figsize=(12,6))
sns.lineplot(data=df_pivot, x=df_pivot.index, y='Fraud Rate (%)', color='purple')
plt.title("Fraud Rate by Hour (%)")
plt.xlabel("Hour Since First Transaction")
plt.ylabel("Fraud Percentage")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# Create a copy for modeling
df_model = df.copy()

# Scale Amount and Time
scaler = StandardScaler()
df_model[['scaled_amount', 'scaled_time']] = scaler.fit_transform(df_model[['Amount', 'Time']])

# Drop original Amount and Time, keep Hour
df_model.drop(['Amount', 'Time'], axis=1, inplace=True)

# Optional: Reorder columns for clarity
columns = ['scaled_amount', 'scaled_time', 'Hour'] + [col for col in df_model.columns if col.startswith('V')] + ['Class']
df_model = df_model[columns]

# Check result
df_model.head()
# Out:
#    scaled_amount  scaled_time  Hour        V1        V2        V3        V4  \
# 0       0.244964    -1.996583     0 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.342475    -1.996583     0  1.191857  0.266151  0.166480  0.448154
# 2       1.160686    -1.996562     0 -1.358354 -1.340163  1.773209  0.379780
# 3       0.140534    -1.996562     0 -0.966272 -0.185226  1.792993 -0.863291
# 4      -0.073403    -1.996541     0 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7  ...       V20       V21       V22       V23  \
# 0 -0.338321  0.462388  0.239599  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.060018 -0.082361 -0.078803  ... -0.069083 -0.225775 -0.638672  0.101288
# 2 -0.503198  1.800499  0.791461  ...  0.524980  0.247998  0.771679  0.909412
# 3 -0.010309  1.247203  0.237609  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.407193  0.095921  0.592941  ...  0.408542 -0.009431  0.798278 -0.137458
#
# ...

# %%
from sklearn.model_selection import train_test_split

# Separate fraud and non-fraud
fraud_df = df_model[df_model['Class'] == 1]
non_fraud_df = df_model[df_model['Class'] == 0]

# Undersample non-fraud to match fraud count
non_fraud_sample = non_fraud_df.sample(n=len(fraud_df), random_state=42)

# Combine and shuffle
balanced_df = pd.concat([fraud_df, non_fraud_sample]).sample(frac=1, random_state=42)

# Split features and target
X = balanced_df.drop('Class', axis=1).values
y = balanced_df['Class'].values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# Confirm shape
print("Train size:", X_train.shape[0])
print("Test size:", X_test.shape[0])
# Out:
# Train size: 787
# Test size: 197

# %%
import torch

# Convert features and labels to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
import torch.nn as nn

# Define the model
class FraudDetector(nn.Module):
    def __init__(self, input_dim):
        super(FraudDetector, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Instantiate the model
model = FraudDetector(input_dim=X_train_tensor.shape[1])

# %%
import torch.optim as optim

# Set optimizer and loss function
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 20
for epoch in range(epochs):
    model.train()

    # Forward pass
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Print training loss
    print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1/20, Loss: 0.7252
# Epoch 2/20, Loss: 0.6906
# Epoch 3/20, Loss: 0.6606
# Epoch 4/20, Loss: 0.6350
# Epoch 5/20, Loss: 0.6133
# Epoch 6/20, Loss: 0.5946
# Epoch 7/20, Loss: 0.5780
# Epoch 8/20, Loss: 0.5626
# Epoch 9/20, Loss: 0.5480
# Epoch 10/20, Loss: 0.5339
# Epoch 11/20, Loss: 0.5202
# Epoch 12/20, Loss: 0.5069
# Epoch 13/20, Loss: 0.4938
# Epoch 14/20, Loss: 0.4810
# Epoch 15/20, Loss: 0.4685
# Epoch 16/20, Loss: 0.4563
# Epoch 17/20, Loss: 0.4444
# Epoch 18/20, Loss: 0.4328
# Epoch 19/20, Loss: 0.4215
# Epoch 20/20, Loss: 0.4104

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Set model to evaluation mode
model.eval()

# Predict probabilities
with torch.no_grad():
    y_pred_probs = model(X_test_tensor).numpy()

# Convert to binary predictions (threshold = 0.5)
y_pred_labels = (y_pred_probs > 0.5).astype(int)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_labels))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Non-Fraud", "Fraud"])
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# ROC AUC score
auc = roc_auc_score(y_test, y_pred_probs)
print(f"ROC AUC Score: {auc:.4f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87        99
#            1       0.93      0.78      0.84        98
#
#     accuracy                           0.86       197
#    macro avg       0.87      0.86      0.86       197
# weighted avg       0.87      0.86      0.86       197
# ROC AUC Score: 0.9169

# %%
# !pip install xgboost

# %%
# Define and train the model
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    use_label_encoder=False,
    random_state=42
)

xgb_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [19:41:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
# ...

# %%
# Predict probabilities and labels
y_pred_probs_xgb = xgb_model.predict_proba(X_test)[:, 1]  # probability of class 1
y_pred_labels_xgb = (y_pred_probs_xgb > 0.5).astype(int)  # convert to 0 or 1

# Classification report
print("XGBoost Classification Report:")
print(classification_report(y_test, y_pred_labels_xgb))

# Confusion matrix
cm_xgb = confusion_matrix(y_test, y_pred_labels_xgb)
disp_xgb = ConfusionMatrixDisplay(confusion_matrix=cm_xgb, display_labels=["Non-Fraud", "Fraud"])
disp_xgb.plot(cmap='Greens')
plt.title("XGBoost Confusion Matrix")
plt.show()

# ROC AUC
roc_auc_xgb = roc_auc_score(y_test, y_pred_probs_xgb)
print(f"XGBoost ROC AUC Score: {roc_auc_xgb:.4f}")
# Out:
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95        99
#            1       0.97      0.92      0.94        98
#
#     accuracy                           0.94       197
#    macro avg       0.95      0.94      0.94       197
# weighted avg       0.95      0.94      0.94       197
# XGBoost ROC AUC Score: 0.9812

# %%
from sklearn.metrics import roc_curve, auc

# ROC for PyTorch
fpr_nn, tpr_nn, _ = roc_curve(y_test, y_pred_probs)  # from earlier PyTorch eval
roc_auc_nn = auc(fpr_nn, tpr_nn)

# ROC for XGBoost
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_pred_probs_xgb)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)

# Plot both
plt.figure(figsize=(10, 6))
plt.plot(fpr_nn, tpr_nn, label=f'PyTorch (AUC = {roc_auc_nn:.2f})', color='orange')
plt.plot(fpr_xgb, tpr_xgb, label=f'XGBoost (AUC = {roc_auc_xgb:.2f})', color='green')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # diagonal reference
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison: PyTorch vs XGBoost')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
